# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings("ignore")

# %matplotlib inline

# %%
df=pd.read_csv("cleaned_google_playstore_data.csv")

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510   8700.0   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967   2800.0    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0      4.0.3
# ...

# %%
df.tail()
# Out:
#                                                  App             Category  \
# 10835                               Sya9a Maroc - FR               FAMILY
# 10836               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10837                         Parkinson Exercices FR              MEDICAL
# 10838                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10839  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating  Reviews     Size  Installs  Type  Price Content Rating  \
# 10835     4.5       38  53000.0      5000  Free    0.0       Everyone
# 10836     5.0        4   3600.0       100  Free    0.0       Everyone
# 10837     NaN        3   9500.0      1000  Free    0.0       Everyone
# 10838     4.5      114      NaN      1000  Free    0.0     Mature 17+
# 10839     4.5   398307  19000.0  10000000  Free    0.0       Everyone
#
#                   Genres Last Updated         Current Ver Android Ver  day  \
# ...

# %%
df.sample(10) # random sample
# Out:
#                                                     App            Category  \
# 8758                            Anti-virus Dr.Web Light               TOOLS
# 1540                               Sad hair without net  LIBRARIES_AND_DEMO
# 4191                        Car Driving Simulator Drift                GAME
# 4927                      All Type Ac Repair & Services           LIFESTYLE
# 590   Hide App, Private Dating, Safe Chat - PrivacyH...              DATING
# 929                                      Comedy Central       ENTERTAINMENT
# 9483   Robot Fighting Games™ - Real Boxing Champions 3D                GAME
# 3947                       Disney Magic Timer by Oral-B              FAMILY
# 920               A&E - Watch Full Episodes of TV Shows       ENTERTAINMENT
# 4573                                             S Note        PRODUCTIVITY
#
#       Rating  Reviews     Size   Installs  Type  Price Content Rating  \
# ...

# %%
df.shape
# Out:
# (10840, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10840 entries, 0 to 10839
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  int64
#  4   Size            9145 non-null   float64
#  5   Installs        10840 non-null  int64
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     9476 non-null   object
#  13  day             10840 non-null  int64
#  14  month           10840 non-null  int64
#  15  year            10840 non-null  int64
# dtypes: float64(3), int64(5), object(8)
# ...

# %%
df.describe() # basic   dicriptive statistics
# Out:
#             Rating       Reviews           Size      Installs         Price  \
# count  9366.000000  1.084000e+04    9145.000000  1.084000e+04  10840.000000
# mean      4.191757  4.441529e+05   21506.534062  1.546434e+07      1.027368
# std       0.515219  2.927761e+06   22596.020795  8.502936e+07     15.949703
# min       1.000000  0.000000e+00      10.000000  0.000000e+00      0.000000
# 25%       4.000000  3.800000e+01    4900.000000  1.000000e+03      0.000000
# 50%       4.300000  2.094000e+03   13000.000000  1.000000e+05      0.000000
# 75%       4.500000  5.477550e+04   30000.000000  5.000000e+06      0.000000
# max       5.000000  7.815831e+07  100000.000000  1.000000e+09    400.000000
#
#                 day         month          year
# count  10840.000000  10840.000000  10840.000000
# mean      15.609041      6.422325   2017.399723
# std        9.561621      2.578388      1.100914
# min        1.000000      1.000000   2010.000000
# ...

# %%
df.describe().T #transpose
# Out:
#             count          mean           std     min     25%       50%  \
# Rating     9366.0  4.191757e+00  5.152189e-01     1.0     4.0       4.3
# Reviews   10840.0  4.441529e+05  2.927761e+06     0.0    38.0    2094.0
# Size       9145.0  2.150653e+04  2.259602e+04    10.0  4900.0   13000.0
# Installs  10840.0  1.546434e+07  8.502936e+07     0.0  1000.0  100000.0
# Price     10840.0  1.027368e+00  1.594970e+01     0.0     0.0       0.0
# day       10840.0  1.560904e+01  9.561621e+00     1.0     6.0      16.0
# month     10840.0  6.422325e+00  2.578388e+00     1.0     5.0       7.0
# year      10840.0  2.017400e+03  1.100914e+00  2010.0  2017.0    2018.0
#
#                 75%           max
# Rating          4.5  5.000000e+00
# Reviews     54775.5  7.815831e+07
# Size        30000.0  1.000000e+05
# Installs  5000000.0  1.000000e+09
# Price           0.0  4.000000e+02
# day            24.0  3.100000e+01
# month           8.0  1.200000e+01
# year         2018.0  2.018000e+03

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510   8700.0   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967   2800.0    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0      4.0.3
# ...

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver', 'day', 'month', 'year'],
#       dtype='object')

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10835                                   Sya9a Maroc - FR               FAMILY
# 10836                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10837                             Parkinson Exercices FR              MEDICAL
# 10838                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10839      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10835    False
# 10836    False
# 10837    False
# 10838    False
# 10839    False
# Length: 10840, dtype: bool

# %%
df[df.duplicated()] # Check the duplicate
# Out:
#                                                    App      Category  Rating  \
# 229                       Quick PDF Scanner + OCR FREE      BUSINESS     4.2
# 236                                                Box      BUSINESS     4.2
# 239                                 Google My Business      BUSINESS     4.4
# 256                                ZOOM Cloud Meetings      BUSINESS     4.4
# 261                          join.me - Simple Meetings      BUSINESS     4.0
# ...                                                ...           ...     ...
# 8643                    Wunderlist: To-Do List & Tasks  PRODUCTIVITY     4.6
# 8654   TickTick: To Do List with Reminder, Day Planner  PRODUCTIVITY     4.6
# 8658                           ColorNote Notepad Notes  PRODUCTIVITY     4.6
# 10049        Airway Ex - Intubate. Anesthetize. Train.       MEDICAL     4.3
# 10767                                             AAFP       MEDICAL     3.8
#
# ...

# %%
df[df.duplicated("App")]
# Out:
#                                       App       Category  Rating  Reviews  \
# 229          Quick PDF Scanner + OCR FREE       BUSINESS     4.2    80805
# 236                                   Box       BUSINESS     4.2   159872
# 239                    Google My Business       BUSINESS     4.4    70991
# 256                   ZOOM Cloud Meetings       BUSINESS     4.4    31614
# 261             join.me - Simple Meetings       BUSINESS     4.0     6989
# ...                                   ...            ...     ...      ...
# 10714                  FarmersOnly Dating         DATING     3.0     1145
# 10719  Firefox Focus: The privacy browser  COMMUNICATION     4.4    36981
# 10729                         FP Notebook        MEDICAL     4.5      410
# 10752      Slickdeals: Coupons & Shopping       SHOPPING     4.5    33599
# 10767                                AAFP        MEDICAL     3.8       63
#
#           Size  Installs  Type  Price Content Rating         Genres  \
# ...

# %%
df[df.duplicated("Reviews")]
# Out:
#                                           App             Category  Rating  \
# 4       Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN     4.3
# 57                 Extreme Rally Championship    AUTO_AND_VEHICLES     4.2
# 126              Skin Care and Natural Beauty               BEAUTY     NaN
# 134             Lady adviser (beauty, health)               BEAUTY     NaN
# 156    Offline: English to Tagalog Dictionary  BOOKS_AND_REFERENCE     4.7
# ...                                       ...                  ...     ...
# 10834                                FR Forms             BUSINESS     NaN
# 10835                        Sya9a Maroc - FR               FAMILY     4.5
# 10836        Fr. Mike Schmitz Audio Teachings               FAMILY     5.0
# 10837                  Parkinson Exercices FR              MEDICAL     NaN
# 10838           The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE     4.5
#
#        Reviews     Size  Installs  Type  Price Content Rating  \
# ...

# %%
df=df.drop_duplicates(subset=["App"],keep='first')  # drop the duplicate value in app column ,keep='first' means keep the only first value

# %%
df.shape
# Out:
# (9659, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9659 entries, 0 to 10839
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9659 non-null   object
#  1   Category        9659 non-null   object
#  2   Rating          8196 non-null   float64
#  3   Reviews         9659 non-null   int64
#  4   Size            8432 non-null   float64
#  5   Installs        9659 non-null   int64
#  6   Type            9658 non-null   object
#  7   Price           9659 non-null   float64
#  8   Content Rating  9659 non-null   object
#  9   Genres          9659 non-null   object
#  10  Last Updated    9659 non-null   object
#  11  Current Ver     9651 non-null   object
#  12  Android Ver     8667 non-null   object
#  13  day             9659 non-null   int64
#  14  month           9659 non-null   int64
#  15  year            9659 non-null   int64
# dtypes: float64(3), int64(5), object(8)
# ...

# %%
numeric_features=[feature for feature in df.columns if df[feature].dtype != 'O']

# %%
numeric_features
# Out:
# ['Rating', 'Reviews', 'Size', 'Installs', 'Price', 'day', 'month', 'year']

# %%
df[numeric_features] # data
# Out:
#        Rating  Reviews     Size  Installs  Price  day  month  year
# 0         4.1      159  19000.0     10000    0.0    7      1  2018
# 1         3.9      967  14000.0    500000    0.0   15      1  2018
# 2         4.7    87510   8700.0   5000000    0.0    1      8  2018
# 3         4.5   215644  25000.0  50000000    0.0    8      6  2018
# 4         4.3      967   2800.0    100000    0.0   20      6  2018
# ...       ...      ...      ...       ...    ...  ...    ...   ...
# 10835     4.5       38  53000.0      5000    0.0   25      7  2017
# 10836     5.0        4   3600.0       100    0.0    6      7  2018
# 10837     NaN        3   9500.0      1000    0.0   20      1  2017
# 10838     4.5      114      NaN      1000    0.0   19      1  2015
# 10839     4.5   398307  19000.0  10000000    0.0   25      7  2018
#
# [9659 rows x 8 columns]

# %%
categorical_features = [feature for feature in df.columns if df[feature].dtype == 'O'] # segrigate the feature based onthe data type

# %%
categorical_features
# Out:
# ['App',
#  'Category',
#  'Type',
#  'Content Rating',
#  'Genres',
#  'Last Updated',
#  'Current Ver',
#  'Android Ver']

# %%
df[categorical_features]
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10835                                   Sya9a Maroc - FR               FAMILY
# 10836                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10837                             Parkinson Exercices FR              MEDICAL
# 10838                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10839      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510   8700.0   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967   2800.0    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0      4.0.3
# ...

# %%
categorical_features
# Out:
# ['App',
#  'Category',
#  'Type',
#  'Content Rating',
#  'Genres',
#  'Last Updated',
#  'Current Ver',
#  'Android Ver']

# %%
df["Type"]
# Out:
# 0        Free
# 1        Free
# 2        Free
# 3        Free
# 4        Free
#          ...
# 10835    Free
# 10836    Free
# 10837    Free
# 10838    Free
# 10839    Free
# Name: Type, Length: 9659, dtype: object

# %%
df["Type"].value_counts()
# Out:
# Free    8902
# Paid     756
# Name: Type, dtype: int64

# %%
df["Type"].value_counts(normalize=True)  # this will get percentage
# Out:
# Free    0.921723
# Paid    0.078277
# Name: Type, dtype: float64

# %%
df["Type"].value_counts(normalize=True)*100 # value count
# Out:
# Free    92.172292
# Paid     7.827708
# Name: Type, dtype: float64

# %%
for col in categorical_features:
    print(f"{col}:{df[col].value_counts(normalize=True)*100}")
    print("=======================================================")
# Out:
# App:Photo Editor & Candy Camera & Grid & ScrapBook    0.010353
# Tic Tac CK                                        0.010353
# INFAMY RO                                         0.010353
# CK Call NEW                                       0.010353
# Ck Coif                                           0.010353
#                                                     ...
# Bike Race Free - Top Motorcycle Racing Games      0.010353
# Dance School Stories - Dance Dreams Come True     0.010353
# 3D Bowling                                        0.010353
# Mind Games Pro                                    0.010353
# iHoroscope - 2018 Daily Horoscope & Astrology     0.010353
# Name: App, Length: 9659, dtype: float64
# ...
# Category:FAMILY                 18.966767
# GAME                    9.928564
# TOOLS                   8.561963
# BUSINESS                4.348276
# MEDICAL                 4.089450
# PERSONALIZATION         3.892743
# PRODUCTIVITY            3.872036
# ...

# %%
sns.countplot(x=df['Type'])
# Out:
# <AxesSubplot: xlabel='Type', ylabel='count'>

# %%
sns.countplot(x=df['Content Rating'])
# Out:
# <AxesSubplot: xlabel='Content Rating', ylabel='count'>

# %%
# categorical columns
plt.figure(figsize=(20, 15))
plt.suptitle('Univariate Analysis of Categorical Features', fontsize=20, fontweight='bold', alpha=0.8, y=1.)
category = [ 'Type', 'Content Rating']
for i in range(0, len(category)):
    plt.subplot(2, 2, i+1)
    sns.countplot(x=df[category[i]],palette="Set2")
    plt.xlabel(category[i])
    plt.xticks(rotation=45)
    plt.tight_layout()

# %%
numeric_features
# Out:
# ['Rating', 'Reviews', 'Size', 'Installs', 'Price', 'day', 'month', 'year']

# %%
sns.kdeplot(df["Price"])
# Out:
# <AxesSubplot: xlabel='Price', ylabel='Density'>

# %%
sns.kdeplot(df["Reviews"])
# Out:
# <AxesSubplot: xlabel='Reviews', ylabel='Density'>

# %%
sns.distplot(df['Reviews'])
# Out:
# <AxesSubplot: xlabel='Reviews', ylabel='Density'>

# %%
sns.kdeplot(df["Rating"])
# Out:
# <AxesSubplot: xlabel='Rating', ylabel='Density'>

# %%
sns.distplot(df['Rating'])
# Out:
# <AxesSubplot: xlabel='Rating', ylabel='Density'>

# %%
plt.hist(df["Rating"])
plt.show()

# %%
plt.figure(figsize=(15, 15))
plt.suptitle('Univariate Analysis of Numerical Features', fontsize=20, fontweight='bold', alpha=0.8, y=1.)

for i in range(0, len(numeric_features)):
    plt.subplot(5, 3, i+1)
    sns.kdeplot(x=df[numeric_features[i]],shade=True, color='r')
    plt.xlabel(numeric_features[i])
    plt.tight_layout()

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510   8700.0   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967   2800.0    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0      4.0.3
# ...

# %%
# univariate analysis

# %%
df["App"]
# Out:
# 0           Photo Editor & Candy Camera & Grid & ScrapBook
# 1                                      Coloring book moana
# 2        U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3                                    Sketch - Draw & Paint
# 4                    Pixel Draw - Number Art Coloring Book
#                                ...
# 10835                                     Sya9a Maroc - FR
# 10836                     Fr. Mike Schmitz Audio Teachings
# 10837                               Parkinson Exercices FR
# 10838                        The SCP Foundation DB fr nn5n
# 10839        iHoroscope - 2018 Daily Horoscope & Astrology
# Name: App, Length: 9659, dtype: object

# %%
df["App"].value_counts()
# Out:
# Photo Editor & Candy Camera & Grid & ScrapBook    1
# Tic Tac CK                                        1
# INFAMY RO                                         1
# CK Call NEW                                       1
# Ck Coif                                           1
#                                                  ..
# Bike Race Free - Top Motorcycle Racing Games      1
# Dance School Stories - Dance Dreams Come True     1
# 3D Bowling                                        1
# Mind Games Pro                                    1
# iHoroscope - 2018 Daily Horoscope & Astrology     1
# Name: App, Length: 9659, dtype: int64

# %%
df["App"].value_counts().plot()
# Out:
# <AxesSubplot: >

# %%
df["Category"].value_counts().plot.pie(y=df["Category"])
# Out:
# <AxesSubplot: ylabel='Category'>

# %%
df["Category"].value_counts().plot.pie(y=df["Category"],figsize=(15,15))
# Out:
# <AxesSubplot: ylabel='Category'>

# %%
df["Category"].value_counts().plot.pie(y=df["Category"],figsize=(15,15),autopct='%1.1f%%')
# Out:
# <AxesSubplot: ylabel='Category'>

# %%
df["Category"].value_counts(10) # top 10 category
# Out:
# FAMILY                 0.189668
# GAME                   0.099286
# TOOLS                  0.085620
# BUSINESS               0.043483
# MEDICAL                0.040895
# PERSONALIZATION        0.038927
# PRODUCTIVITY           0.038720
# LIFESTYLE              0.038203
# FINANCE                0.035718
# SPORTS                 0.033647
# COMMUNICATION          0.032612
# HEALTH_AND_FITNESS     0.029817
# PHOTOGRAPHY            0.029092
# NEWS_AND_MAGAZINES     0.026297
# SOCIAL                 0.024744
# BOOKS_AND_REFERENCE    0.022984
# TRAVEL_AND_LOCAL       0.022673
# SHOPPING               0.020913
# DATING                 0.017704
# VIDEO_PLAYERS          0.016875
# MAPS_AND_NAVIGATION    0.013562
# EDUCATION              0.012320
# FOOD_AND_DRINK         0.011595
# ENTERTAINMENT          0.010560
# AUTO_AND_VEHICLES      0.008800
# LIBRARIES_AND_DEMO     0.008697
# WEATHER                0.008179
# HOUSE_AND_HOME         0.007661
# EVENTS                 0.006626
# ...

# %%
sns.barplot(df["Category"].value_counts(10))
# Out:
# <AxesSubplot: xlabel='Category'>

# %%
df_cat=df["Category"].value_counts()[:10]

# %%
category = pd.DataFrame(df['Category'].value_counts())        #Dataframe of apps on the basis of category
category.rename(columns = {'Category':'Count'},inplace=True)

# %%
plt.figure(figsize=(15,6))
sns.barplot(x=df_cat, y ='Count',data = category[:10],palette='hls')
plt.title('Top 10 App categories')
plt.xticks(rotation=90)
plt.show()

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510   8700.0   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967   2800.0    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0      4.0.3
# ...

# %%
# which category having largest number of instalation

# %%
df.groupby(df["Category"])["Installs"].sum().sort_values()  # ascending order
# Out:
# Category
# EVENTS                    15973161
# BEAUTY                    27197050
# PARENTING                 31521110
# MEDICAL                   38193177
# COMICS                    44981150
# LIBRARIES_AND_DEMO        52995910
# AUTO_AND_VEHICLES         53130211
# HOUSE_AND_HOME            97212461
# ART_AND_DESIGN           114338100
# DATING                   140926107
# FOOD_AND_DRINK           211798751
# EDUCATION                352952000
# WEATHER                  361100520
# FINANCE                  455348734
# MAPS_AND_NAVIGATION      503281890
# LIFESTYLE                503823539
# BUSINESS                 697164865
# SPORTS                  1096474498
# HEALTH_AND_FITNESS      1144022512
# SHOPPING                1400348785
# PERSONALIZATION         1532494782
# BOOKS_AND_REFERENCE     1665969576
# ENTERTAINMENT           2113660000
# NEWS_AND_MAGAZINES      2369217760
# TRAVEL_AND_LOCAL        2894887146
# VIDEO_PLAYERS           3926902720
# ...

# %%
df.groupby(df["Category"])["Installs"].sum().sort_values(ascending=False) # Descending
# Out:
# Category
# GAME                   13878924415
# COMMUNICATION          11038276251
# TOOLS                   8001771915
# PRODUCTIVITY            5793091369
# SOCIAL                  5487867902
# PHOTOGRAPHY             4649147655
# FAMILY                  4427941505
# VIDEO_PLAYERS           3926902720
# TRAVEL_AND_LOCAL        2894887146
# NEWS_AND_MAGAZINES      2369217760
# ENTERTAINMENT           2113660000
# BOOKS_AND_REFERENCE     1665969576
# PERSONALIZATION         1532494782
# SHOPPING                1400348785
# HEALTH_AND_FITNESS      1144022512
# SPORTS                  1096474498
# BUSINESS                 697164865
# LIFESTYLE                503823539
# MAPS_AND_NAVIGATION      503281890
# FINANCE                  455348734
# WEATHER                  361100520
# EDUCATION                352952000
# FOOD_AND_DRINK           211798751
# DATING                   140926107
# ART_AND_DESIGN           114338100
# HOUSE_AND_HOME            97212461
# ...

# %%
df_cat_installs=df.groupby(df["Category"])["Installs"].sum().sort_values(ascending=False).reset_index()

# %%
df_cat_installs
# Out:
#                Category     Installs
# 0                  GAME  13878924415
# 1         COMMUNICATION  11038276251
# 2                 TOOLS   8001771915
# 3          PRODUCTIVITY   5793091369
# 4                SOCIAL   5487867902
# 5           PHOTOGRAPHY   4649147655
# 6                FAMILY   4427941505
# 7         VIDEO_PLAYERS   3926902720
# 8      TRAVEL_AND_LOCAL   2894887146
# 9    NEWS_AND_MAGAZINES   2369217760
# 10        ENTERTAINMENT   2113660000
# 11  BOOKS_AND_REFERENCE   1665969576
# 12      PERSONALIZATION   1532494782
# 13             SHOPPING   1400348785
# 14   HEALTH_AND_FITNESS   1144022512
# 15               SPORTS   1096474498
# 16             BUSINESS    697164865
# 17            LIFESTYLE    503823539
# 18  MAPS_AND_NAVIGATION    503281890
# 19              FINANCE    455348734
# 20              WEATHER    361100520
# 21            EDUCATION    352952000
# 22       FOOD_AND_DRINK    211798751
# 23               DATING    140926107
# ...

# %%
df2=df_cat_installs.head(10)

# %%
df2
# Out:
#              Category     Installs
# 0                GAME  13878924415
# 1       COMMUNICATION  11038276251
# 2               TOOLS   8001771915
# 3        PRODUCTIVITY   5793091369
# 4              SOCIAL   5487867902
# 5         PHOTOGRAPHY   4649147655
# 6              FAMILY   4427941505
# 7       VIDEO_PLAYERS   3926902720
# 8    TRAVEL_AND_LOCAL   2894887146
# 9  NEWS_AND_MAGAZINES   2369217760

# %%
sns.barplot(x="Installs",y="Category",data=df2)
# Out:
# <AxesSubplot: xlabel='Installs', ylabel='Category'>

# %%
plt.figure(figsize = (14,10))
sns.set_context("talk")
sns.set_style("darkgrid")

ax = sns.barplot(x = 'Installs' , y = 'Category' , data = df2 )
ax.set_xlabel('No. of Installations in Billions')
ax.set_ylabel('')
ax.set_title("Most Popular Categories in Play Store", size = 20)
# Out:
# Text(0.5, 1.0, 'Most Popular Categories in Play Store')

# %%
 # What are the Top 5 most installed Apps in Each popular Categories ??

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510   8700.0   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967   2800.0    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0      4.0.3
# ...

# %%
dfa=df.groupby(['Category','App'])['Installs'].sum().reset_index()

# %%
dfa
# Out:
#             Category                                                App  \
# 0     ART_AND_DESIGN                           350 Diy Room Decor Ideas
# 1     ART_AND_DESIGN    3D Color Pixel by Number - Sandbox Art Coloring
# 2     ART_AND_DESIGN                            AJ Styles HD Wallpapers
# 3     ART_AND_DESIGN  AJ Styles Wallpaper 2018 - AJ Styles HD Wallpaper
# 4     ART_AND_DESIGN                              Ai illustrator viewer
# ...              ...                                                ...
# 9654         WEATHER                                      Yahoo Weather
# 9655         WEATHER  Yahoo! Weather for SH Forecast for understandi...
# 9656         WEATHER                                     Yandex.Weather
# 9657         WEATHER                         weather - weather forecast
# 9658         WEATHER                     wetter.com - Weather and Radar
#
#       Installs
# 0        10000
# 1       100000
# 2         5000
# 3         1000
# 4       100000
# ...

# %%
dfa=dfa.sort_values('Installs',ascending=False)

# %%
dfa[dfa.Category=='GAME'][:5]
# Out:
#      Category               App    Installs
# 4773     GAME    Subway Surfers  1000000000
# 4167     GAME  Candy Crush Saga   500000000
# 4628     GAME               Pou   500000000
# 4802     GAME      Temple Run 2   500000000
# 4580     GAME    My Talking Tom   500000000

# %%
dfa[dfa.Category=='PRODUCTIVITY'][:5]
# Out:
#           Category              App    Installs
# 7427  PRODUCTIVITY     Google Drive  1000000000
# 7472  PRODUCTIVITY   Microsoft Word   500000000
# 7425  PRODUCTIVITY  Google Calendar   500000000
# 7364  PRODUCTIVITY          Dropbox   500000000
# 7334  PRODUCTIVITY      Cloud Print   500000000

# %%
dfa[dfa.Category=='FAMILY'][:5]
# Out:
#      Category                            App   Installs
# 3333   FAMILY               Tom Loves Angela  100000000
# 3290   FAMILY              Talking Tom Cat 2  100000000
# 1976   FAMILY  Bitmoji – Your Personal Emoji  100000000
# 3289   FAMILY                Talking Tom Cat  100000000
# 3287   FAMILY         Talking Tom & Ben News  100000000

# %%
apps = ['GAME', 'COMMUNICATION', 'PRODUCTIVITY', 'SOCIAL' ]
sns.set_context("poster")
sns.set_style("darkgrid")

plt.figure(figsize=(40,30))

for i,app in enumerate(apps):
    df2 = dfa[dfa.Category == app]
    df3 = df2.head(5)
    plt.subplot(4,2,i+1)
    sns.barplot(data= df3,x= 'Installs' ,y='App' )
    plt.xlabel('Installation in Millions')
    plt.ylabel('')
    plt.title(app,size = 20)
    
plt.tight_layout()
plt.subplots_adjust(hspace= .3)
plt.show()

# %%
# How many apps are there on Google Play Store which get 5 ratings??

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510   8700.0   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967   2800.0    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0      4.0.3
# ...

# %%
df.groupby(["App"])["Rating"].sum()
# Out:
# App
# "i DT" Fútbol. Todos Somos Técnicos.                0.0
# +Download 4 Instagram Twitter                       4.5
# - Free Comics - Comic Apps                          3.5
# .R                                                  4.5
# /u/app                                              4.7
#                                                    ...
# 뽕티비 - 개인방송, 인터넷방송, BJ방송                             0.0
# 💎 I'm rich                                          3.8
# 💘 WhatsLov: Smileys of love, stickers and GIF       4.6
# 📏 Smart Ruler ↔️ cm/inch measuring for homework!    4.0
# 🔥 Football Wallpapers 4K | Full HD Backgrounds 😍    4.7
# Name: Rating, Length: 9659, dtype: float64

# %%
rating=df.groupby(["App"])["Rating"].sum().sort_values(ascending=False).reset_index()

# %%
rating[rating.Rating==5.0]
# Out:
#                                                   App  Rating
# 0                           Comunidad De Fe Minitries     5.0
# 1                                     Tablet Reminder     5.0
# 2                               Noticias FC Barcelona     5.0
# 3    Superheroes, Marvel, DC, Comics, TV, Movies News     5.0
# 4                   DC N COMPANY ENTERTAINMENT RADIO!     5.0
# ..                                                ...     ...
# 266                     American Girls Mobile Numbers     5.0
# 267                                         daskal.eu     5.0
# 268                         Free coupons and vouchers     5.0
# 269                                      Bk Usha behn     5.0
# 270                           Asha Ek Hope - ALS/ MND     5.0
#
# [271 rows x 2 columns]

# %%
rating2 = df.groupby(['Category','Installs', 'App'])['Rating'].sum().sort_values(ascending = False).reset_index()

# %%
rating2
# Out:
#             Category  Installs  \
# 0             FAMILY      1000
# 1             DATING       100
# 2             FAMILY        10
# 3             DATING       500
# 4            MEDICAL         5
# ...              ...       ...
# 9654           TOOLS       100
# 9655           TOOLS       100
# 9656        BUSINESS       100
# 9657           TOOLS       100
# 9658  ART_AND_DESIGN         0
#
#                                                    App  Rating
# 0                          CS & IT Interview Questions     5.0
# 1                              Online Girls Chat Group     5.0
# 2                                        Chronolink DX     5.0
# 3                                Spine- The dating app     5.0
# 4                                    Clinic Doctor EHr     5.0
# ...                                                ...     ...
# 9654                                         CG Wizard     0.0
# 9655  CG 3D Model Viewer: view 3D models interactively     0.0
# ...

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver', 'day', 'month', 'year'],
#       dtype='object')

# %%
plt.figure(figsize=(15,15))
sns.scatterplot(data=df,y="Category",x="Price")
# Out:
# <AxesSubplot: xlabel='Price', ylabel='Category'>

# %%
# which category app users are reviewing the most ???

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510   8700.0   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967   2800.0    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0      4.0.3
# ...

# %%
df.groupby(['Category','App'])['Reviews'].sum().sort_values(ascending = False).reset_index()
# Out:
#                  Category                                       App   Reviews
# 0                  SOCIAL                                  Facebook  78158306
# 1           COMMUNICATION                        WhatsApp Messenger  69119316
# 2                  SOCIAL                                 Instagram  66577313
# 3           COMMUNICATION  Messenger – Text and Video Chat for Free  56642847
# 4                    GAME                            Clash of Clans  44891723
# ...                   ...                                       ...       ...
# 9654            LIFESTYLE                                        DT         0
# 9655                TOOLS                             AQ SMS Notify         0
# 9656                TOOLS                               AQ wisdom +         0
# 9657  BOOKS_AND_REFERENCE                               Schlaumeier         0
# 9658              MEDICAL                    POCKET BOOK CT ABDOMEN         0
#
# [9659 rows x 3 columns]

# %%
df.groupby("Category").agg({"Installs":"sum","Reviews":"sum"}).reset_index()  # aggrigation
# Out:
#                Category     Installs    Reviews
# 0        ART_AND_DESIGN    114338100    1419203
# 1     AUTO_AND_VEHICLES     53130211    1163666
# 2                BEAUTY     27197050     396240
# 3   BOOKS_AND_REFERENCE   1665969576   16721314
# 4              BUSINESS    697164865    9890245
# 5                COMICS     44981150    2342071
# 6         COMMUNICATION  11038276251  285811368
# 7                DATING    140926107    3623544
# 8             EDUCATION    352952000   13364148
# 9         ENTERTAINMENT   2113660000   34762650
# 10               EVENTS     15973161     161018
# 11               FAMILY   4427941505  143825488
# 12              FINANCE    455348734   12662106
# 13       FOOD_AND_DRINK    211798751    6325028
# 14                 GAME  13878924415  622298709
# 15   HEALTH_AND_FITNESS   1144022512   21361355
# 16       HOUSE_AND_HOME     97212461    1929847
# 17   LIBRARIES_AND_DEMO     52995910     906831
# 18            LIFESTYLE    503823539   11832671
# ...

# %%
df.groupby('Type').agg({'Installs':sum}).plot.pie(y='Installs')
# Out:
# <AxesSubplot: ylabel='Installs'>

# %%
df.value_counts('Type').plot.pie(y='Type')
# Out:
# <AxesSubplot: ylabel='None'>

# %%
fig, ax = plt.subplots(1,2,figsize=(20,7))
df.value_counts('Type').plot.pie(y='Type',startangle=90, explode=(0.2,0), title='Percentage of the Free App and Paid App', legend=False, autopct='%.2f', ax=ax[0])
ax[0].set(ylabel='Type of Apps')
df.groupby('Type').agg({'Installs':sum}).plot.pie(y='Installs', startangle=90, explode=(0.2,0), title='Percentage of Installs Number for Free App and Paid App', legend=False, autopct='%.2f', ax=ax[1])
# Out:
# <AxesSubplot: title={'center': 'Percentage of Installs Number for Free App and Paid App'}, ylabel='Installs'>

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510   8700.0   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967   2800.0    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0      4.0.3
# ...

# %%
sns.boxplot(x="Installs",y="Rating",data=df)
# Out:
# <AxesSubplot: xlabel='Installs', ylabel='Rating'>

# %%
plt.figure(figsize=(10,10))
sns.boxplot(x="Installs",y="Rating",data=df)
plt.xticks(size=15,rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.boxplot(x="Category",y="Rating",data=df)
plt.xticks(size=15,rotation=90)
plt.show()

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510   8700.0   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967   2800.0    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0      4.0.3
# ...

# %%
# Which category apps are og largest size ??

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver', 'day', 'month', 'year'],
#       dtype='object')

# %%
sns.barplot("Category","Size",data=df)
# Out:
# <AxesSubplot: xlabel='Category', ylabel='Size'>

# %%
plt.figure(figsize=(15,15))
plt.xticks(rotation = 90)
sns.barplot('Category','Size',data=df)
plt.show()

# %%
plt.subplots(figsize=(20,10))
freq= pd.Series()
freq=df['year'].value_counts()
freq.plot()
plt.xlabel("Dates")
plt.ylabel("Number of updates")
plt.title("Time series plot of Last Updates")
# Out:
# Text(0.5, 1.0, 'Time series plot of Last Updates')

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510   8700.0   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967   2800.0    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0      4.0.3
# ...

# %%
plt.figure(figsize=(15,8))
sns.countplot(x='Rating',data = df,palette="Set1_r")
plt.xticks(rotation =90)
plt.title('Countplot for ratings')             
plt.show()
